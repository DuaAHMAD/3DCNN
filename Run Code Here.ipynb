# %%
# !python -m train.py --datasets BDI_DERIVED --output /timo/code/Duaa/3DCNN/output/ --batch 50 --epochs 50 --lr 1e-4
# Out:
# Summary of Arguments:
# dataroot   /timo/datasets/AV/BDI/Temp_from_ext_HDD/OLD60AlignedFaces/{exp}
# datasets   BDI_DERIVED
# workers    4
# batch      50
# epochs     50
# cpu        False
# seed       2572
# checkpoint None
# output     /timo/code/Duaa/3DCNN/output/
# print_freq 10
# visualize  False
# lr         0.0001
# submedian  False
# overwrite  False
# augment    False
# # of params: 335938
# sum of pred is:  22.132837 29
# Training epoch 1 [   0/ 404]: 1.0023s/batch, 0.0971s on gpu, 0.9051s on data    loss: 0.67457825    loss_avg:0.67457825
# Training epoch 1 [  10/ 404]: 2.0151s/batch, 0.1093s on gpu, 1.8992s on data    loss: 0.48300171    loss_avg:0.56477039
# Training epoch 1 [  20/ 404]: 1.9899s/batch, 0.1119s on gpu, 1.8779s on data    loss: 0.32456267    loss_avg:0.46089349
# Training epoch 1 [  30/ 404]: 2.8335s/batch, 0.0992s on gpu, 2.7343s on data    loss: 0.21440105    loss_avg:0.39054972
# ...
